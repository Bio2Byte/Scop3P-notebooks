# %% [markdown]
# # Protein topology viewer

# %%
from IPython.display import display
from topology import make_app

display(make_app())

# %% [markdown]
# ### Fallback: skip the widget entirely
#
# ```python
# from topology import save_html
# save_html('P07949', 'ret_topology.html')     # by accession
# save_html('my_prediction.pdb', 'out.html')   # by file
# ```
