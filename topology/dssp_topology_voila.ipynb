# %% [markdown]
# # AlphaFold Topology Viewer
#
# Fetch an AlphaFold DB mmCIF or upload a local CIF/DSSP file, then render an interactive clean topology linked to Mol*.

# %%
from IPython.display import display
from dssp_topology_app import make_app

display(make_app())
